# %%
from utilsADCN import cifarLoaderAllChannels, plotPerformance
from ADCNbasic import ADCN
from ADCNmainloop import ADCNmain
from model import ConvAeCIFAR
import numpy as np
import pdb
import torch
import random
from torchvision import datasets, transforms

# %%
# random seed control
np.random.seed(0)
torch.manual_seed(0)
random.seed(0)

# %%
# convert data to torch.FloatTensor
# transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5,0.5,0.5))])
transform = transforms.ToTensor()

# load the training and test datasets
labeledData   = datasets.CIFAR10(root='data', train=False,download=True, transform=transform)
unlabeledData = datasets.CIFAR10(root='data', train=True, download=True, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
dataStream = cifarLoaderAllChannels(labeledData, unlabeledData, nEachClassSamples = 500)
# Out:
# Number of output:  10
# Number of labeled data:  5000
# Number of unlabeled data:  55000
# Number of unlabeled data batch:  55

# %%
dataStream.createDrift(nDrift = 4, taskList = [[0,5],[6,10],[11,15],[0,15]], taskType = 2)

# %%
# Check for cude or mps or cpu
if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

# %%
allMetrics = []

# %%
nNodeInit  = 96  
nIn        = 768  
n_trials   = 5
batch_size = 16 #

# %%
for i_trial in range(0, n_trials):
    print('Trial: ', i_trial)
    ADCNnet         = ADCN(dataStream.nOutput, nInput = nIn, nHiddenNode = nNodeInit)
    ADCNnet.ADCNcnn = ConvAeCIFAR()
    ADCNnet, performanceHistory, allPerformance = ADCNmain(ADCNnet, dataStream, trainingBatchSize = batch_size, device = device)
    allMetrics.append(allPerformance)
# Out:
# Trial:  0
# Network initialization phase is started
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# +++ Grow node +++
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
# --- Prune node ---
#
#
# Cluster initialization phase is started
# A cluster was created containing  2166  centroids
# 0 -th batch
# /Users/seanfuhrman/Desktop/Current Programs/SEELab/Master's/UCL for IDS/AutonomousDCN/ADCNbasic.py:377: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/python_arg_parser.cpp:1630.)
#   loss.add_(self.regStrClusteringLoss/2,clusteringLoss(latentAE, oneHotClusters, centroids))
# Accuracy:  26.9
# 1 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.026911163702607155 ; Error bound warning:  0.4796334207057953 ; Error bound drift:  0.5279765725135803
# Status: STABLE
# 2 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03209127485752106 ; Error bound warning:  0.48015356063842773 ; Error bound drift:  0.5285492539405823
# Status: STABLE
# 3 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.01596681773662567 ; Error bound warning:  0.48098018765449524 ; Error bound drift:  0.5294591784477234
# Status: STABLE
# 4 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.0330224446952343 ; Error bound warning:  0.48470214009284973 ; Error bound drift:  0.5335562229156494
# Status: STABLE
# 5 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.05581548810005188 ; Error bound warning:  0.4917847812175751 ; Error bound drift:  0.5413527488708496
# Status: STABLE
# 6 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02486993931233883 ; Error bound warning:  0.4904271066188812 ; Error bound drift:  0.5398582816123962
# Status: STABLE
# 7 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.026051795110106468 ; Error bound warning:  0.4860961139202118 ; Error bound drift:  0.5350906848907471
# Status: STABLE
# 8 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03699425235390663 ; Error bound warning:  0.48667600750923157 ; Error bound drift:  0.5357290506362915
# Status: STABLE
# 9 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02756231278181076 ; Error bound warning:  0.48856624960899353 ; Error bound drift:  0.5378097891807556
# Status: STABLE
# 10 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.047604482620954514 ; Error bound warning:  0.4868314564228058 ; Error bound drift:  0.5359001755714417
# Status: STABLE
# Accuracy:  26.636363636363637
# 11 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.01802387274801731 ; Error bound warning:  0.4832756221294403 ; Error bound drift:  0.5319859385490417
# Status: STABLE
# 12 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03312794864177704 ; Error bound warning:  0.48084723949432373 ; Error bound drift:  0.529312789440155
# Status: STABLE
# 13 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04060693457722664 ; Error bound warning:  0.4828213155269623 ; Error bound drift:  0.5314857959747314
# Status: STABLE
# 14 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.031094929203391075 ; Error bound warning:  0.4832595884799957 ; Error bound drift:  0.5319684147834778
# Status: STABLE
# 15 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.025260992348194122 ; Error bound warning:  0.4841519296169281 ; Error bound drift:  0.5329505801200867
# Status: STABLE
# 16 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03164282441139221 ; Error bound warning:  0.4840606153011322 ; Error bound drift:  0.5328500270843506
# Status: STABLE
# 17 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02496749721467495 ; Error bound warning:  0.48435619473457336 ; Error bound drift:  0.5331754088401794
# Status: STABLE
# 18 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.06016319617629051 ; Error bound warning:  0.47957852482795715 ; Error bound drift:  0.5279162526130676
# Status: STABLE
# 19 -th batch
# A cut point is detected cut:  1000
# H0 is NOT rejected, size: 0.027755236253142357 ; Error bound warning:  0.27504763007164 ; Error bound drift:  0.3027702569961548
# Status: STABLE
# 20 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02298317290842533 ; Error bound warning:  0.48001599311828613 ; Error bound drift:  0.528397798538208
# Status: STABLE
# Accuracy:  26.404761904761898
# 21 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.05594731867313385 ; Error bound warning:  0.48372361063957214 ; Error bound drift:  0.5324790477752686
# Status: STABLE
# 22 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.060309141874313354 ; Error bound warning:  0.4808250367641449 ; Error bound drift:  0.5292884111404419
# Status: STABLE
# 23 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.043875206261873245 ; Error bound warning:  0.4796331822872162 ; Error bound drift:  0.5279764533042908
# Status: STABLE
# 24 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.022547071799635887 ; Error bound warning:  0.47932693362236023 ; Error bound drift:  0.5276393294334412
# Status: STABLE
# 25 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02562403492629528 ; Error bound warning:  0.4800140857696533 ; Error bound drift:  0.5283955931663513
# Status: STABLE
# 26 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02309752069413662 ; Error bound warning:  0.4775376617908478 ; Error bound drift:  0.5256696939468384
# Status: STABLE
# 27 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02362126298248768 ; Error bound warning:  0.47812584042549133 ; Error bound drift:  0.5263171195983887
# Status: STABLE
# 28 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.023067228496074677 ; Error bound warning:  0.4816725254058838 ; Error bound drift:  0.5302212238311768
# Status: STABLE
# 29 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03744122385978699 ; Error bound warning:  0.4828897714614868 ; Error bound drift:  0.5315611362457275
# Status: STABLE
# 30 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02555263787508011 ; Error bound warning:  0.4813568592071533 ; Error bound drift:  0.529873788356781
# Status: STABLE
# Accuracy:  26.529032258064515
# 31 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.0311457309871912 ; Error bound warning:  0.4804116189479828 ; Error bound drift:  0.5288332104682922
# Status: STABLE
# 32 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03515510633587837 ; Error bound warning:  0.47694525122642517 ; Error bound drift:  0.5250175595283508
# Status: STABLE
# 33 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.027830086648464203 ; Error bound warning:  0.47619184851646423 ; Error bound drift:  0.524188220500946
# Status: STABLE
# 34 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.05944101884961128 ; Error bound warning:  0.4770137369632721 ; Error bound drift:  0.5250928997993469
# Status: STABLE
# 35 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03520863875746727 ; Error bound warning:  0.4776171147823334 ; Error bound drift:  0.5257571339607239
# Status: STABLE
# 36 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.032716404646635056 ; Error bound warning:  0.47851911187171936 ; Error bound drift:  0.5267500281333923
# Status: STABLE
# 37 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.032709550112485886 ; Error bound warning:  0.47756147384643555 ; Error bound drift:  0.5256958603858948
# Status: STABLE
# 38 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.040436964482069016 ; Error bound warning:  0.4794289767742157 ; Error bound drift:  0.5277515649795532
# Status: STABLE
# 39 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.040235668420791626 ; Error bound warning:  0.4785058796405792 ; Error bound drift:  0.5267354846000671
# Status: STABLE
# 40 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03915055841207504 ; Error bound warning:  0.4772860109806061 ; Error bound drift:  0.5253927111625671
# Status: STABLE
# Accuracy:  26.595121951219515
# 41 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02534240297973156 ; Error bound warning:  0.48068687319755554 ; Error bound drift:  0.5291362404823303
# Status: STABLE
# 42 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02914184331893921 ; Error bound warning:  0.48085856437683105 ; Error bound drift:  0.5293252468109131
# Status: STABLE
# 43 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03673425689339638 ; Error bound warning:  0.47858643531799316 ; Error bound drift:  0.5268241167068481
# Status: STABLE
# 44 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.031396474689245224 ; Error bound warning:  0.4766111373901367 ; Error bound drift:  0.5246497392654419
# Status: STABLE
# 45 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.046457577496767044 ; Error bound warning:  0.47873762249946594 ; Error bound drift:  0.5269905924797058
# Status: STABLE
# 46 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.024533860385417938 ; Error bound warning:  0.4775632619857788 ; Error bound drift:  0.5256978869438171
# Status: STABLE
# 47 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03565254807472229 ; Error bound warning:  0.478021502494812 ; Error bound drift:  0.5262022614479065
# Status: STABLE
# 48 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.02516300231218338 ; Error bound warning:  0.481865257024765 ; Error bound drift:  0.5304333567619324
# Status: STABLE
# 49 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.03715965151786804 ; Error bound warning:  0.48217806220054626 ; Error bound drift:  0.5307777523994446
# Status: STABLE
# 50 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.023834936320781708 ; Error bound warning:  0.4800339937210083 ; Error bound drift:  0.5284176468849182
# Status: STABLE
# Accuracy:  26.633333333333336
# 51 -th batch
# A cut point is detected cut:  500
# H0 is NOT rejected, size: 0.04555903747677803 ; Error bound warning:  0.48130109906196594 ; Error bound drift:  0.5298125147819519
# Status: STABLE
#
#
# === Performance result ===
# Accuracy:  26.609615384615388 (+/-) 1.4262996253598943
# ARI:  0.04970778386638146
# NMI:  0.07907215097286524
# F1 score:  0.26222838186816577
# Precision:  0.26590870450002513
# Recall:  0.26609615384615387
# Testing Time:  0.9914390307206374 (+/-) 0.07542634816199327
# Training Time:  1414.113624045482 (+/-) 0.7873917060670368
#
#
# === Average network evolution ===
# Number of layer:  1.0 (+/-) 0.0
# Total hidden node:  396.0 (+/-) 0.0
# Number of cluster:  2527.346153846154 (+/-) 135.22856500347626
#
#
# === Final network structure ===
# basicAE(
#   (linear): Linear(in_features=768, out_features=396, bias=True)
#   (activation): ReLU(inplace=True)
# )
# No. of AE inputs : 768
# No. of AE nodes : 396
# No. of AE parameters : 305292
# Trial:  1
# Network initialization phase is started
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 5
#       3 ADCNnet         = ADCN(dataStream.nOutput, nInput = nIn, nHiddenNode = nNodeInit)
#       4 ADCNnet.ADCNcnn = ConvAeCIFAR()
# ----> 5 ADCNnet, performanceHistory, allPerformance = ADCNmain(ADCNnet, dataStream, trainingBatchSize = batch_size, device = device)
#       6 allMetrics.append(allPerformance)
#
# File ~/Desktop/Current Programs/SEELab/Master's/UCL for IDS/AutonomousDCN/ADCNmainloop.py:40, in ADCNmain(ADCNnet, dataStreams, nLabeled, layerGrowing, nodeEvolution, clusterGrowing, lwfLoss, clusteringLoss, trainingBatchSize, noOfEpoch, device)
#      38 # initialization phase
#      39 start_initialization_train = time.time()
# ---> 40 ADCNnet.initialization(dataStreams.labeledData, layerCount,
#      41                         batchSize = trainingBatchSize, device = device)
#      43 if nLabeled == 1:
#      44     allegianceData  = dataStreams.labeledData.clone()
#
# File ~/Desktop/Current Programs/SEELab/Master's/UCL for IDS/AutonomousDCN/ADCNbasic.py:184, in ADCN.initialization(self, labeledData, winIdx, batchSize, epoch, device)
#     181 print('Network initialization phase is started')
#     183 # Train CNN, for the first training, epoch is used
# --> 184 latentFeatures = self.trainCNN(labeledData, unlabeled = False, epoch = epoch)
#     186 # Train AE, this trains the newly created layer
#     187 latentFeatures = self.trainBasicAe(latentFeatures, labeledData, evolving = self.evolving, winIdx = 0, epoch = epoch, unlabeled = False)
#
# File ~/Desktop/Current Programs/SEELab/Master's/UCL for IDS/AutonomousDCN/ADCNbasic.py:251, in ADCN.trainCNN(self, x, unlabeled, epoch)
#     247 optimizer.zero_grad()
#     249 # forward
#     250 # latentAE here is the output of the deepest autoencoder
# --> 251 latentFeatures = self.ADCNcnn(minibatch_xTrain)     # encode
#     252 outputs        = self.ADCNcnn(latentFeatures, 2)    # decode
#     254 # calculate the reconstruction loss
#
# File ~/opt/anaconda3/envs/cl4ids/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/cl4ids/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Desktop/Current Programs/SEELab/Master's/UCL for IDS/AutonomousDCN/model.py:515, in ConvAeCIFAR.forward(self, x, mode)
#     512 if mode == 1:
#     513     ## encode ##
#     514     x = F.relu(self.conv1(x))
# --> 515     x = F.relu(self.conv2(x))
#     516     x = F.relu(self.conv3(x))
#     517     x = x.view(x.size(0),-1)
#
# File ~/opt/anaconda3/envs/cl4ids/lib/python3.11/site-packages/torch/nn/functional.py:1473, in relu(input, inplace)
#    1471     result = torch.relu_(input)
#    1472 else:
# -> 1473     result = torch.relu(input)
#    1474 return result
#
# KeyboardInterrupt:

# %%
# all results

# 0: accuracy
# 1: ARI
# 2: NMI
# 3: f1_score
# 4: precision_score
# 5: recall_score
# 6: training_time
# 7: testingTime
# 8: nHiddenLayer
# 9: nHiddenNode
# 10: nCluster

meanResults = np.round_(np.mean(allMetrics,0), decimals=2)
stdResults  = np.round_(np.std(allMetrics,0), decimals=2)

print('\n')
print('========== Performance CIFAR10 ==========')
print('Preq Accuracy: ', meanResults[0].item(), '(+/-)',stdResults[0].item())
print('ARI: ', meanResults[1].item(), '(+/-)',stdResults[1].item())
print('NMI: ', meanResults[2].item(), '(+/-)',stdResults[2].item())
print('F1 score: ', meanResults[3].item(), '(+/-)',stdResults[3].item())
print('Precision: ', meanResults[4].item(), '(+/-)',stdResults[4].item())
print('Recall: ', meanResults[5].item(), '(+/-)',stdResults[5].item())
print('Training time: ', meanResults[6].item(), '(+/-)',stdResults[6].item())
print('Testing time: ', meanResults[7].item(), '(+/-)',stdResults[7].item())

print('\n')
print('========== Network ==========')
print('Number of hidden layers: ', meanResults[8].item(), '(+/-)',stdResults[8].item())
print('Number of features: ', meanResults[9].item(), '(+/-)',stdResults[9].item())
print('Number of clusters: ', meanResults[10].item(), '(+/-)',stdResults[10].item())
# Out:
# ========== Performance KMNIST ==========
# Preq Accuracy:  26.85 (+/-) 0.88
# ARI:  0.05 (+/-) 0.01
# NMI:  0.08 (+/-) 0.01
# F1 score:  0.26 (+/-) 0.01
# Precision:  0.27 (+/-) 0.01
# Recall:  0.27 (+/-) 0.01
# Training time:  669.47 (+/-) 125.35
# Testing time:  1.0 (+/-) 0.2
#
#
# ========== Network ==========
# Number of hidden layers:  1.0 (+/-) 0.0
# Number of features:  352.0 (+/-) 97.31
# Number of clusters:  2739.4 (+/-) 109.91
